# %%
import numpy as np
import matplotlib.pyplot as plt

rsquare = np.array([0.415, 0.490, 0.921, 0.945, 0.985, 0.997])
rmse = np.sqrt(np.array([0.016329657286405563, 0.016082774980791976, 0.004773773419271622, 0.0009064425581267902, 0.00036498501348043125, 7.846510249822001e-05]))
beta = ["5", "1", "0.1", "0.01", "0.001", "0.0001"]

plt.bar(beta, rmse, color='blue')
plt.xlabel("Beta Value")
plt.ylabel("RMSE")
# Out:
# Text(0, 0.5, 'RMSE')

# %%
all_rmses = np.array([0.01591819, 0.01618065, 0.000285, 0.000798])
models = ['Baseline VAE', 'Convolutional VAE', 'BetaVAE', 'InfoVAE']

plt.bar(models, all_rmses, color='blue')
plt.xlabel("Model Type")
plt.ylabel("Best RMSE Achieved")
# Out:
# Text(0, 0.5, 'Best RMSE Achieved')

# %%
all_rsquare = np.array([0.478, 0.425, 0.997, 0.971])
models = ['Baseline VAE', 'Convolutional VAE', 'BetaVAE', 'InfoVAE']

plt.bar(models, all_rsquare, color='green')
plt.xlabel("Model Type")
plt.ylabel("Best Population R-squared Achieved")
# Out:
# Text(0, 0.5, 'Best Population R-squared Achieved')

# %%
all_rsquare = np.array([0, 0, 0.946, 0.787])
models = ['Baseline VAE', 'Convolutional VAE', 'BetaVAE', 'InfoVAE']

plt.bar(models, all_rsquare, color='purple')
plt.xlabel("Model Type")
plt.ylabel("Best Parameter R-squared Achieved")
# Out:
# Text(0, 0.5, 'Best Parameter R-squared Achieved')
